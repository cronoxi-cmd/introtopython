# %%
import random
import pandas as pd

# Define some lists of adjectives and products
adjectives = ["formal", "elegant", "trendy", "vintage", "silk"]
products = ["dress", "handbag", "shoes", "sunglasses", "tie"]

# Define a class for product
class Product:
    # Initialize a product with three adjectives and a random price
    def __init__(self):
        self.name = " ".join([random.choice(adjectives) for _ in range(3)]) + " " + random.choice(products)
        self.price = round(random.uniform(50, 500), 2)  # Adjusted price range for items

    # Return the name and price of the product
    def __str__(self):
        return self.name + " ($" + str(self.price) + ")"

# Define a class for customer
class Customer:
    # Initialize a customer with a name and a basket
    def __init__(self, name):
        self.name = name
        self.basket = Basket()  # Initialize an empty basket for the customer

    def get_name(self):
        return self.name

    # Return the name and the basket of the customer
    def __str__(self):
        return self.name   #+ " (" + str(self.basket) + ")"

# Define a class for basket
class Basket:
    # Initialize a basket with an empty list of products
    def __init__(self):
        self.products = []

    # Add a product to the basket
    def add(self, product):
        self.products.append(product)

    # Calculate total price of items in the basket
    def calculate_total(self):
        total = 0
        for product in self.products:
            total += product.price
        return round(total, 2)

    # Return the list of products in the basket
    def __str__(self):
        result = "Basket:\n"
        for product in self.products:
            result += str(product) + "\n"
        return result

# Define a class for inventory
class Inventory:
    # Initialize the inventory with a list of products
    def __init__(self, num_products=10):
        self.products = [Product() for _ in range(num_products)]

    # Display the product inventory
    def display_inventory(self):
        print("Product Inventory:")
        for idx, product in enumerate(self.products, start=1):
            print(f"{idx}. {product}")

    # Calculate total price of items in the inventory
    def calculate_total(self):
        total = 0
        for product in self.products:
            total += product.price
        return round(total, 2)

# Define a class for store
class Stand:
    # Initialize a store with a name, an inventory, a list of customers, and a sale object
    def __init__(self, name):
        self.name = name
        self.inventory = Inventory()
        self.customers = []

    # Add a customer to the store
    def add_customer(self, customer):
        self.customers.append(customer)

    def get_customers(self):
        print("\nCustomers in the store:")
        for customer in self.customers:
            print(customer.get_name() + " is shopping.")

    def display_inventory(self):
        self.inventory.display_inventory()

    # Run the simulation for the store
    def run(self):
        print("Welcome to " + self.name + "!")
        self.inventory.display_inventory()
        print("We have " + str(len(self.customers)) + " customers today.")

        for customer in self.customers: # Iterate over the customers
            print("Customer " + customer.get_name() + " is shopping.")
            basket = Basket()  # Create a basket for the customer
            for _ in range(random.randint(1, 5)):  # Randomly add 1 to 5 products to the basket
                product = random.choice(self.inventory.products)
                basket.add(product)
                print("Customer " + customer.get_name() + " added " + str(product) + " to their basket.")
            total_price = basket.calculate_total()  # Calculate total price
            print("Customer " + customer.get_name() + " checked out and paid $" + str(total_price) + ".")
            print()
        return self.inventory.calculate_total()  # Return total sales for the store

# Define a class for corporation
class Corporation:
    # Initialize a corporation with a name and a list of stores
    def __init__(self, name):
        self.name = name
        self.stands = []

    # Add a store to the corporation
    def add_stand(self, stand):
        self.stands.append(stand)

    # Run the simulation for the corporation
    def simulate(self):
        print("Welcome to " + self.name + "!")
        print("We have " + str(len(self.stands)) + " stores in our corporation.")
        # Iterate over the stores
        total_sales = 0
        store_analytics = []
        for store in self.stands:
            # Run the simulation for each store
            total_sales += store.run()
            # Record store analytics
            store_analytics.append({'name': store.name, 'total_sales': total_sales})
        print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")
        return store_analytics

    # Get analytics for all stores
    def get_analytics(self):
        store_analytics = []
        for store in self.stands:
            store_analytics.append({'name': store.name, 'total_sales': store.inventory.calculate_total()})
        return store_analytics

# Define a class for analytics
class Analytics:
    def __init__(self):
        self.store_analytics = []

    def add_analytics(self, analytics):  #send it your collected store results
        self.store_analytics = analytics

    def make_csv(self):
        df = pd.DataFrame(self.store_analytics)
        entitle = "latest-store.csv"  #title for the file we'll build from it
        df.to_csv(entitle)

# Create a corporation object
corp = Corporation("Vincent's Amazing Corporation")

# Create some store objects and add them to the corporation
store1 = Stand("Crystal Clear Clothing")
store2 = Stand("ZPP Frontier")
store3 = Stand("Hello Outfitters")
corp.add_stand(store1)
corp.add_stand(store2)
corp.add_stand(store3)

# Define a list of customer names
customer_names = ["alex", "jeff", "zoe", "bob", "stefan", "daniel"]

# Add customers to the stores
for name in customer_names:
    store1.add_customer(Customer(name))
    store2.add_customer(Customer(name))
    store3.add_customer(Customer(name))

# Simulate the corporation
corp.simulate()

# Display analytics and save to CSV
analytic = Analytics()
analytic.add_analytics(corp.get_analytics())
analytic.make_csv()
# Out:
# Welcome to Vincent's Amazing Corporation!
# We have 3 stores in our corporation.
# Welcome to Crystal Clear Clothing!
# Product Inventory:
# 1. trendy formal elegant tie ($94.08)
# 2. silk vintage silk dress ($387.36)
# 3. elegant elegant elegant dress ($420.71)
# 4. formal trendy trendy handbag ($215.51)
# 5. vintage vintage trendy tie ($183.93)
# 6. silk elegant trendy sunglasses ($65.76)
# 7. vintage trendy formal handbag ($320.32)
# 8. formal formal silk dress ($392.7)
# 9. trendy vintage vintage sunglasses ($360.54)
# 10. silk elegant formal dress ($103.84)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added trendy formal elegant tie ($94.08) to their basket.
# Customer alex added silk elegant trendy sunglasses ($65.76) to their basket.
# Customer alex added formal formal silk dress ($392.7) to their basket.
# Customer alex added trendy formal elegant tie ($94.08) to their basket.
# Customer alex added trendy formal elegant tie ($94.08) to their basket.
# Customer alex checked out and paid $740.7.
#
# Customer jeff is shopping.
# Customer jeff added trendy vintage vintage sunglasses ($360.54) to their basket.
# Customer jeff checked out and paid $360.54.
#
# Customer zoe is shopping.
# Customer zoe added silk elegant formal dress ($103.84) to their basket.
# Customer zoe added silk vintage silk dress ($387.36) to their basket.
# Customer zoe added silk vintage silk dress ($387.36) to their basket.
# Customer zoe added silk elegant formal dress ($103.84) to their basket.
# Customer zoe added trendy formal elegant tie ($94.08) to their basket.
# Customer zoe checked out and paid $1076.48.
#
# Customer bob is shopping.
# Customer bob added trendy formal elegant tie ($94.08) to their basket.
# Customer bob added formal formal silk dress ($392.7) to their basket.
# Customer bob added trendy vintage vintage sunglasses ($360.54) to their basket.
# Customer bob checked out and paid $847.32.
#
# Customer stefan is shopping.
# Customer stefan added formal trendy trendy handbag ($215.51) to their basket.
# Customer stefan added formal trendy trendy handbag ($215.51) to their basket.
# Customer stefan checked out and paid $431.02.
#
# Customer daniel is shopping.
# Customer daniel added silk elegant formal dress ($103.84) to their basket.
# Customer daniel added silk vintage silk dress ($387.36) to their basket.
# Customer daniel added silk vintage silk dress ($387.36) to their basket.
# Customer daniel checked out and paid $878.56.
#
# Welcome to ZPP Frontier!
# Product Inventory:
# 1. elegant silk vintage shoes ($80.25)
# 2. elegant vintage silk handbag ($435.94)
# 3. formal silk vintage handbag ($204.98)
# 4. silk vintage elegant shoes ($73.81)
# 5. elegant formal formal dress ($59.71)
# 6. vintage silk silk handbag ($398.69)
# 7. vintage silk elegant sunglasses ($357.1)
# 8. vintage trendy trendy sunglasses ($365.34)
# 9. silk vintage trendy dress ($385.29)
# 10. elegant vintage silk sunglasses ($446.6)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added silk vintage elegant shoes ($73.81) to their basket.
# Customer alex added formal silk vintage handbag ($204.98) to their basket.
# Customer alex added silk vintage trendy dress ($385.29) to their basket.
# Customer alex checked out and paid $664.08.
#
# Customer jeff is shopping.
# Customer jeff added silk vintage trendy dress ($385.29) to their basket.
# Customer jeff added elegant formal formal dress ($59.71) to their basket.
# Customer jeff added elegant vintage silk handbag ($435.94) to their basket.
# Customer jeff added silk vintage elegant shoes ($73.81) to their basket.
# Customer jeff added vintage silk silk handbag ($398.69) to their basket.
# Customer jeff checked out and paid $1353.44.
#
# Customer zoe is shopping.
# Customer zoe added elegant vintage silk sunglasses ($446.6) to their basket.
# Customer zoe added elegant vintage silk sunglasses ($446.6) to their basket.
# Customer zoe added vintage silk silk handbag ($398.69) to their basket.
# Customer zoe added silk vintage elegant shoes ($73.81) to their basket.
# Customer zoe added vintage silk silk handbag ($398.69) to their basket.
# Customer zoe checked out and paid $1764.39.
#
# Customer bob is shopping.
# Customer bob added silk vintage trendy dress ($385.29) to their basket.
# Customer bob checked out and paid $385.29.
#
# Customer stefan is shopping.
# Customer stefan added elegant silk vintage shoes ($80.25) to their basket.
# Customer stefan added elegant vintage silk handbag ($435.94) to their basket.
# Customer stefan added formal silk vintage handbag ($204.98) to their basket.
# Customer stefan added elegant vintage silk handbag ($435.94) to their basket.
# Customer stefan checked out and paid $1157.11.
#
# Customer daniel is shopping.
# Customer daniel added elegant vintage silk handbag ($435.94) to their basket.
# Customer daniel added vintage trendy trendy sunglasses ($365.34) to their basket.
# Customer daniel checked out and paid $801.28.
#
# Welcome to Hello Outfitters!
# Product Inventory:
# 1. formal formal trendy tie ($235.02)
# 2. vintage silk trendy shoes ($126.16)
# 3. vintage vintage vintage tie ($198.79)
# 4. trendy formal silk tie ($450.43)
# 5. silk vintage silk sunglasses ($236.31)
# 6. silk vintage vintage dress ($115.43)
# 7. formal trendy formal dress ($341.56)
# 8. trendy trendy silk shoes ($452.42)
# 9. trendy formal elegant dress ($199.62)
# 10. formal elegant vintage shoes ($112.25)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added vintage vintage vintage tie ($198.79) to their basket.
# Customer alex added formal formal trendy tie ($235.02) to their basket.
# Customer alex added silk vintage silk sunglasses ($236.31) to their basket.
# Customer alex added trendy trendy silk shoes ($452.42) to their basket.
# Customer alex checked out and paid $1122.54.
#
# Customer jeff is shopping.
# Customer jeff added trendy formal elegant dress ($199.62) to their basket.
# Customer jeff added trendy formal silk tie ($450.43) to their basket.
# Customer jeff added vintage silk trendy shoes ($126.16) to their basket.
# Customer jeff checked out and paid $776.21.
#
# Customer zoe is shopping.
# Customer zoe added formal elegant vintage shoes ($112.25) to their basket.
# Customer zoe checked out and paid $112.25.
#
# Customer bob is shopping.
# Customer bob added silk vintage silk sunglasses ($236.31) to their basket.
# Customer bob added vintage silk trendy shoes ($126.16) to their basket.
# Customer bob checked out and paid $362.47.
#
# Customer stefan is shopping.
# Customer stefan added trendy formal elegant dress ($199.62) to their basket.
# Customer stefan added vintage vintage vintage tie ($198.79) to their basket.
# Customer stefan added silk vintage silk sunglasses ($236.31) to their basket.
# Customer stefan added formal trendy formal dress ($341.56) to their basket.
# Customer stefan added formal formal trendy tie ($235.02) to their basket.
# Customer stefan checked out and paid $1211.3.
#
# Customer daniel is shopping.
# Customer daniel added trendy formal silk tie ($450.43) to their basket.
# Customer daniel added silk vintage silk sunglasses ($236.31) to their basket.
# Customer daniel added trendy formal silk tie ($450.43) to their basket.
# Customer daniel added silk vintage vintage dress ($115.43) to their basket.
# Customer daniel checked out and paid $1252.6.
#
# The total sales for Vincent's Amazing Corporation today is $7820.45.
