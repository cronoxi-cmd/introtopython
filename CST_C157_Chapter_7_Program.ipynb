# %%
import random

# Define some lists of adjectives and products
adjectives = ["formal", "elegant", "trendy", "vintage", "silk"]
products = ["dress", "handbag", "shoes", "sunglasses", "tie"]

# Define a class for product
class Product:
    # Initialize a product with three adjectives and a random price
    def __init__(self):
        self.name = " ".join([random.choice(adjectives) for _ in range(3)]) + " " + random.choice(products)
        self.price = round(random.uniform(50, 500), 2)  # Adjusted price range for items

    # Return the name and price of the product
    def __str__(self):
        return self.name + " ($" + str(self.price) + ")"

# Define a class for customer
class Customer:
    # Initialize a customer with a name and a basket
    def __init__(self, name):
        self.name = name
        self.basket = Basket()  # Initialize an empty basket for the customer

    def get_name(self):
        return self.name

    # Return the name and the basket of the customer
    def __str__(self):
        return self.name   #+ " (" + str(self.basket) + ")"

# Define a class for basket
class Basket:
    # Initialize a basket with an empty list of products
    def __init__(self):
        self.products = []

    # Add a product to the basket
    def add(self, product):
        self.products.append(product)

    # Calculate total price of items in the basket
    def calculate_total(self):
        total = 0
        for product in self.products:
            total += product.price
        return round(total, 2)

    # Return the list of products in the basket
    def __str__(self):
        result = "Basket:\n"
        for product in self.products:
            result += str(product) + "\n"
        return result

# Define a class for inventory
class Inventory:
    # Initialize the inventory with a list of products
    def __init__(self, num_products=10):
        self.products = [Product() for _ in range(num_products)]

    # Display the product inventory
    def display_inventory(self):
        print("Product Inventory:")
        for idx, product in enumerate(self.products, start=1):
            print(f"{idx}. {product}")

    # Calculate total price of items in the inventory
    def calculate_total(self):
        total = 0
        for product in self.products:
            total += product.price
        return round(total, 2)

# Define a class for store
class Stand:
    # Initialize a store with a name, an inventory, a list of customers, and a sale object
    def __init__(self, name):
        self.name = name
        self.inventory = Inventory()
        self.customers = []

    # Add a customer to the store
    def add_customer(self, customer):
        self.customers.append(customer)

    def get_customers(self):
        print("\nCustomers in the store:")
        for customer in self.customers:
            print(customer.get_name() + " is shopping.")

    def display_inventory(self):
        self.inventory.display_inventory()

    # Run the simulation for the store
    def run(self):
        print("Welcome to " + self.name + "!")
        self.inventory.display_inventory()
        print("We have " + str(len(self.customers)) + " customers today.")

        for customer in self.customers: # Iterate over the customers
            print("Customer " + customer.get_name() + " is shopping.")
            basket = Basket()  # Create a basket for the customer
            for _ in range(random.randint(1, 5)):  # Randomly add 1 to 5 products to the basket
                product = random.choice(self.inventory.products)
                basket.add(product)
                print("Customer " + customer.get_name() + " added " + str(product) + " to their basket.")
            total_price = basket.calculate_total()  # Calculate total price
            print("Customer " + customer.get_name() + " checked out and paid $" + str(total_price) + ".")
            print()

# Define a class for corporation
class Corporation:
    # Initialize a corporation with a name and a list of stores
    def __init__(self, name):
        self.name = name
        self.stands = []

    # Add a store to the corporation
    def add_stand(self, stand):
        self.stands.append(stand)

    # Run the simulation for the corporation
    def simulate(self):
        print("Welcome to " + self.name + "!")
        print("We have " + str(len(self.stands)) + " stores in our corporation.")
        # Iterate over the stores
        total_sales = 0
        for store in self.stands:
            # Run the simulation for each store
            store.run()
            # Calculate the total sales for the corporation
            total_sales += store.inventory.calculate_total()
        print("The total sales for " + self.name + " today is $" + str(total_sales) + ".")

    # Return the name and the list of stores of the corporation
    def __str__(self):
        result = self.name + ":\n"
        for stand in self.stands:
            result += str(stand) + "\n"
        return result

# Create a corporation object
corp = Corporation("Vincent's Amazing Corporation")

# Create some store objects and add them to the corporation
store1 = Stand("Crystal Clear Clothing")
store2 = Stand("ZPP Frontier")
store3 = Stand("Hello Outfitters")
corp.add_stand(store1)
corp.add_stand(store2)
corp.add_stand(store3)

# Define a list of customer names
customer_names = ["alex", "jeff", "zoe", "bob", "stefan", "daniel"]

# Add customers to the stores
for name in customer_names:
    store1.add_customer(Customer(name))
    store2.add_customer(Customer(name))
    store3.add_customer(Customer(name))

# Simulate the corporation
corp.simulate()
# Out:
# Welcome to Vincent's Amazing Corporation!
# We have 3 stores in our corporation.
# Welcome to Crystal Clear Clothing!
# Product Inventory:
# 1. silk trendy formal handbag ($120.11)
# 2. elegant vintage silk tie ($161.65)
# 3. elegant formal vintage tie ($439.73)
# 4. vintage trendy vintage tie ($99.6)
# 5. vintage elegant trendy handbag ($169.92)
# 6. elegant trendy silk shoes ($91.11)
# 7. silk formal trendy shoes ($187.66)
# 8. silk formal trendy handbag ($201.74)
# 9. silk formal silk tie ($257.05)
# 10. trendy formal vintage tie ($95.28)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added elegant trendy silk shoes ($91.11) to their basket.
# Customer alex added silk formal trendy handbag ($201.74) to their basket.
# Customer alex added silk formal trendy handbag ($201.74) to their basket.
# Customer alex checked out and paid $494.59.
#
# Customer jeff is shopping.
# Customer jeff added silk trendy formal handbag ($120.11) to their basket.
# Customer jeff checked out and paid $120.11.
#
# Customer zoe is shopping.
# Customer zoe added silk formal trendy shoes ($187.66) to their basket.
# Customer zoe checked out and paid $187.66.
#
# Customer bob is shopping.
# Customer bob added vintage elegant trendy handbag ($169.92) to their basket.
# Customer bob checked out and paid $169.92.
#
# Customer stefan is shopping.
# Customer stefan added elegant vintage silk tie ($161.65) to their basket.
# Customer stefan added vintage elegant trendy handbag ($169.92) to their basket.
# Customer stefan checked out and paid $331.57.
#
# Customer daniel is shopping.
# Customer daniel added elegant formal vintage tie ($439.73) to their basket.
# Customer daniel added silk formal silk tie ($257.05) to their basket.
# Customer daniel checked out and paid $696.78.
#
# Welcome to ZPP Frontier!
# Product Inventory:
# 1. elegant formal vintage tie ($214.52)
# 2. trendy silk vintage sunglasses ($223.84)
# 3. trendy vintage silk shoes ($499.41)
# 4. trendy elegant silk tie ($268.91)
# 5. trendy formal vintage sunglasses ($435.06)
# 6. elegant silk trendy sunglasses ($149.22)
# 7. trendy trendy elegant sunglasses ($152.98)
# 8. vintage formal vintage dress ($65.21)
# 9. formal trendy elegant dress ($451.23)
# 10. trendy formal formal tie ($189.11)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added formal trendy elegant dress ($451.23) to their basket.
# Customer alex added formal trendy elegant dress ($451.23) to their basket.
# Customer alex added trendy trendy elegant sunglasses ($152.98) to their basket.
# Customer alex checked out and paid $1055.44.
#
# Customer jeff is shopping.
# Customer jeff added formal trendy elegant dress ($451.23) to their basket.
# Customer jeff added trendy trendy elegant sunglasses ($152.98) to their basket.
# Customer jeff checked out and paid $604.21.
#
# Customer zoe is shopping.
# Customer zoe added trendy vintage silk shoes ($499.41) to their basket.
# Customer zoe added trendy formal formal tie ($189.11) to their basket.
# Customer zoe added trendy trendy elegant sunglasses ($152.98) to their basket.
# Customer zoe added formal trendy elegant dress ($451.23) to their basket.
# Customer zoe added trendy elegant silk tie ($268.91) to their basket.
# Customer zoe checked out and paid $1561.64.
#
# Customer bob is shopping.
# Customer bob added trendy silk vintage sunglasses ($223.84) to their basket.
# Customer bob added formal trendy elegant dress ($451.23) to their basket.
# Customer bob added trendy elegant silk tie ($268.91) to their basket.
# Customer bob checked out and paid $943.98.
#
# Customer stefan is shopping.
# Customer stefan added trendy silk vintage sunglasses ($223.84) to their basket.
# Customer stefan added elegant formal vintage tie ($214.52) to their basket.
# Customer stefan checked out and paid $438.36.
#
# Customer daniel is shopping.
# Customer daniel added trendy elegant silk tie ($268.91) to their basket.
# Customer daniel checked out and paid $268.91.
#
# Welcome to Hello Outfitters!
# Product Inventory:
# 1. vintage elegant trendy tie ($495.38)
# 2. vintage trendy elegant dress ($469.13)
# 3. vintage elegant vintage shoes ($357.33)
# 4. trendy silk formal sunglasses ($490.9)
# 5. elegant formal formal handbag ($141.59)
# 6. vintage formal silk shoes ($90.64)
# 7. vintage silk vintage shoes ($479.05)
# 8. elegant formal silk shoes ($377.15)
# 9. trendy formal silk handbag ($229.33)
# 10. vintage vintage elegant handbag ($449.16)
# We have 6 customers today.
# Customer alex is shopping.
# Customer alex added trendy formal silk handbag ($229.33) to their basket.
# Customer alex added elegant formal silk shoes ($377.15) to their basket.
# Customer alex added trendy silk formal sunglasses ($490.9) to their basket.
# Customer alex added vintage silk vintage shoes ($479.05) to their basket.
# Customer alex added vintage formal silk shoes ($90.64) to their basket.
# Customer alex checked out and paid $1667.07.
#
# Customer jeff is shopping.
# Customer jeff added vintage formal silk shoes ($90.64) to their basket.
# Customer jeff added trendy formal silk handbag ($229.33) to their basket.
# Customer jeff added elegant formal silk shoes ($377.15) to their basket.
# Customer jeff checked out and paid $697.12.
#
# Customer zoe is shopping.
# Customer zoe added vintage trendy elegant dress ($469.13) to their basket.
# Customer zoe added trendy silk formal sunglasses ($490.9) to their basket.
# Customer zoe added trendy formal silk handbag ($229.33) to their basket.
# Customer zoe added elegant formal formal handbag ($141.59) to their basket.
# Customer zoe checked out and paid $1330.95.
#
# Customer bob is shopping.
# Customer bob added trendy formal silk handbag ($229.33) to their basket.
# Customer bob added elegant formal silk shoes ($377.15) to their basket.
# Customer bob added vintage formal silk shoes ($90.64) to their basket.
# Customer bob added trendy silk formal sunglasses ($490.9) to their basket.
# Customer bob added trendy formal silk handbag ($229.33) to their basket.
# Customer bob checked out and paid $1417.35.
#
# Customer stefan is shopping.
# Customer stefan added vintage silk vintage shoes ($479.05) to their basket.
# Customer stefan checked out and paid $479.05.
#
# Customer daniel is shopping.
# Customer daniel added vintage elegant vintage shoes ($357.33) to their basket.
# Customer daniel checked out and paid $357.33.
#
# The total sales for Vincent's Amazing Corporation today is $8053.0.
